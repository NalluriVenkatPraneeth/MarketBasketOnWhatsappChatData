# %%
import pandas as pd

# %%
data = pd.read_csv('wtsapdata.csv')
data = data.iloc[:,1:]

# %%
data = data.drop(['time','Am/Pm','Message'],axis=1)
data
# Out:
#           date                    Name
# 0     18/02/21       Supriya Panigrahi
# 1     18/02/21          Saksham Bansal
# 2     18/02/21          Saksham Bansal
# 3     18/02/21                Praneeth
# 4     18/02/21  Kaustubh Arun Shingana
# ...        ...                     ...
# 7310  16/07/21            Yash Kanakia
# 7311  16/07/21            Yash Kanakia
# 7312  16/07/21                Praneeth
# 7313  16/07/21             Roona Shree
# 7314  16/07/21            Yash Kanakia
#
# [7315 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7315 entries, 0 to 7314
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    7315 non-null   object
#  1   Name    7315 non-null   object
# dtypes: object(2)
# memory usage: 114.4+ KB

# %%
#mlxtend package for association rule algo
#apriori algo and association rules generation
from mlxtend.frequent_patterns import apriori, association_rules

#preprocessing module for transaction encoder
from mlxtend.preprocessing import TransactionEncoder

# %%
transactions
# Out:
# [['R Satish Srinivas',
#   'R Satish Srinivas',
#   'Supriya Panigrahi',
#   'Neha Afreen',
#   'Supriya Panigrahi',
#   'R Satish Srinivas',
#   'Rohit Sabu',
#   'Rakesh Babu Gedela',
#   'Rakesh Babu Gedela',
#   'Saksham Bansal',
#   'Saksham Bansal',
#   'R Satish Srinivas',
#   'Rakesh Babu Gedela',
#   'Neha Afreen',
#   'Harshit Arun',
#   'Vaibhav V',
#   'Supriya Panigrahi',
#   'Supriya Panigrahi',
#   'R Satish Srinivas',
#   'Neha Afreen',
#   'Saksham Bansal',
#   'Ujjwal Shekhar',
#   'Saksham Bansal',
#   'Umesh Pachpute',
#   'Abhinil Banerjee'],
#  ['Abhishek Unnikrishnan',
#   'Ujjwal Shekhar',
#   'Abhishek Unnikrishnan',
#   'Roona Shree',
#   'Saksham Bansal',
#   'Saksham Bansal',
#   'Vamsi',
#   'Neha Afreen',
#   'Yash Kanakia',
#   'Neha Afreen',
#   'Yash Kanakia',
#   'Neha Afreen',
#   'Yash Kanakia',
#   'Abhishek Unnikrishnan',
#   'Aishwarya Chougule',
#   'Aishwarya Chougule',
#   'Abhishek Unnikrishnan',
#   'Yash Kanakia',
#   'Yash Kanakia',
# ...

# %%
transactions1
# Out:
#      Abhinil Banerjee  Abhishek Unnikrishnan  Aishwarya Chougule  \
# 0                True                  False               False
# 1               False                   True                True
# 2               False                  False                True
# 3               False                   True               False
# 4               False                   True                True
# ..                ...                    ...                 ...
# 140             False                   True                True
# 141             False                  False                True
# 142             False                   True                True
# 143             False                  False                True
# 144             False                  False                True
#
#      Harshit Arun  Harshit Manishbhai Bardana  Karthik  \
# 0            True                       False    False
# 1           False                       False    False
# ...

# %%
#Grouping the data by user
#Converting that to a list
#using the tolist() to convert the Names to a list which is stored in the variable a as 'Names'
transactions = [a[1]['Name'].tolist() for a in list(data.groupby(["date"]))]

#Initializing the object for TransactionEncoder()
transEnco = TransactionEncoder()

#Using this object to transform this data of 'Names' to a transaction data of binary values
trans_array = transEnco.fit(transactions).transform(transactions)

#converting this array of binary values into a dataframe with column names
transactions1 = pd.DataFrame(trans_array, columns=transEnco.columns_)

# %%
frequent_itemsets = apriori(df=transactions1,min_support=0.2,use_colnames=True)

# %%
frequent_itemsets
# Out:
#        support                                           itemsets
# 0     0.227586                                 (Abhinil Banerjee)
# 1     0.434483                            (Abhishek Unnikrishnan)
# 2     0.544828                               (Aishwarya Chougule)
# 3     0.275862                       (Harshit Manishbhai Bardana)
# 4     0.262069                                          (Karthik)
# ...        ...                                                ...
# 4297  0.206897  (Aishwarya Chougule, Roona Shree, Rohit Sabu, ...
# 4298  0.200000  (Aishwarya Chougule, Ujjwal Shekhar, Roona Shr...
# 4299  0.206897  (Aishwarya Chougule, Ujjwal Shekhar, Roona Shr...
# 4300  0.220690  (Aishwarya Chougule, Ujjwal Shekhar, Roona Shr...
# 4301  0.213793  (Aishwarya Chougule, Ujjwal Shekhar, Roona Shr...
#
# [4302 rows x 2 columns]

# %%
#Generating the association rules from mlxtend package
#imposing min confidence threshold as 50 percentage
rules = association_rules(frequent_itemsets)

# %%
#Displaying sorted rules in descending order of lift value
ne = rules.sort_values(by='lift',ascending=False)

# %%
pd.set_option()

# %%
from pandas import option_context

with option_context('display.max_colwidth', 400):
    display(ne.head())
# Out:
#                                                                                        antecedents  \
# 45731  (Aishwarya Chougule, Ujjwal Shekhar, Umesh Pachpute, Saksham Bansal, Abhishek Unnikrishnan)
# 45746    (Aishwarya Chougule, Umesh Pachpute, Saksham Bansal, Abhishek Unnikrishnan, Yash Kanakia)
# 39297                        (Aishwarya Chougule, Abhishek Unnikrishnan, Saksham Bansal, Praneeth)
# 40659                   (Umesh Pachpute, Abhishek Unnikrishnan, Supriya Panigrahi, Saksham Bansal)
# 45766                  (Aishwarya Chougule, Abhishek Unnikrishnan, Umesh Pachpute, Saksham Bansal)
#
#                                                                       consequents  \
# 45731                  (R Satish Srinivas, Yash Kanakia, Roona Shree, Rohit Sabu)
# 45746                (R Satish Srinivas, Ujjwal Shekhar, Roona Shree, Rohit Sabu)
# 39297                (R Satish Srinivas, Umesh Pachpute, Roona Shree, Rohit Sabu)
# ...
